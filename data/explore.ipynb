# %%
import pandas as pd

# %%
brand = pd.read_csv("developer_brand.csv", sep=";")
# brand.head(20)
# developer_brand.csv
# developer_main.csv24 days ago
# district_province_id.csva month ago
# facility_id.csva month ago
# Hackathon data dictionary.xlsx19 days ago
# LICENSE.txt18 days ago
# project_description.csv19 days ago
# project_facility.csva month ago
# project_main.csv24 days ago
# project_unit.csva month ago
# unit_type_id.csva month ago
# userLog_201801_201802_for_participants.csv
brand
# Out:
#       developer_id  brand_id                       brand_name_th  \
# 0              128       379                         เอสต้า บลิซ
# 1              176      1496   บริษัท ชัยยุทธ เรียล เอสเตท จำกัด
# 2              226      1819              อะพูล คอนโด แอท บางนา
# 3              143      1567            คาซ่า ฟรานซ์ เอแบค-บางนา
# 4              250       436                            เลอ นีโอ
# 5             3588       442                                 NaN
# 6             9339      1468     บริษัท คีย์ สตาร์ พร็อพเพอร์ตี้
# 7             9234      1602     พาร์ค วิลเลจ อ่อนนุช-สุวรรณภูมิ
# 8             3647       701                   เชียงใหม่พฤกษาโฮม
# 9             6248      1346           รื่นฤดี 4 (รังสิต-คลอง 4)
# 10           15650      1768     เดอะ มาร์ค รัชดา-แอร์พอร์ตลิงค์
# 11            6559       846                              เอสเคป
# 12            1205       465                                 NaN
# ...

# %%
user_log = pd.read_csv("userLog_201801_201802_for_participants.csv", sep=";")

# %%
user_log.tail(20)
# Out:
#                                      userCode  project_id requestedDevice  \
# 1234559  50194307-ac1a-8fdd-c0d2-920ea71a78b5        6443          Mobile
# 1234560  39178c5e-8d92-5a37-634c-b35d9fcc516b        9400          Mobile
# 1234561  db06471d-b0c2-2429-bf58-a7e822f837d7        9472         Desktop
# 1234562  efb828ef-0a75-c6ed-a11d-deca11049e9d        8112          Mobile
# 1234563  45df04d6-1d7e-06a8-0a8e-2c5c382689b6        8534         Desktop
# 1234564  db06471d-b0c2-2429-bf58-a7e822f837d7        9472         Desktop
# 1234565  7a35eb91-2581-170d-a56b-406405f156c7        7241          Mobile
# 1234566  01ff0d39-da3c-65c2-661a-9ffaac29ddb3        4713          Mobile
# 1234567  b5ae099c-1054-f38c-c178-05d9670980db        5239          Mobile
# 1234568  891ee206-2488-6b6a-d9e1-21987c26f6bf        9447          Mobile
# 1234569  ab8efc26-e6f3-2055-4d07-d7e70bf0d7d4        9095          Mobile
# 1234570  7a35eb91-2581-170d-a56b-406405f156c7        7241          Mobile
# ...

# %%
project_description = pd.read_csv("project_description.csv", sep=";")

# %%
project_description['description_th'][0]
# Out:
# 'ตั้งอยู่ติดถนนรังสิต-นครนายก  จัดแบ่งผังโครงการเพื่อให้ผู้อยู่อาศัยได้สัมผัสกับธรรมชาติของน้ำด้วยคลอง กว้าง 10 เมตร และทะเลสาบ 2 แห่ง สิ่งอำนวยความสะดวกครบ ใกล้สถานศึกษามหาวิทยาลัย เดินทางสะดวกสบายด้วยถนนวงแหวนตะวันออก'

# %%
proj_unit = pd.read_csv("project_unit.csv", sep=";")
